# %%
from __future__ import annotations

import operator
from typing import TypedDict, List, Annotated, Literal

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

from pathlib import Path

# %%
class Task(BaseModel):
    id: int
    title: str
    goal: str = Field(..., description="One sentence describing what the reader should be able to do/understand after this section")
    bullets: List[str] = Field(..., min_length=3, max_length=5, description="3-5 concrete, non-overlapping subpoints to cover in this section.")
    target_words: int = Field(..., description="Target word count for this section (120-450)")
    section_type: Literal["intro", "core", "examples", "checklist", "common_mistakes", "conclusion"] = Field(..., description="Use 'common_mistakes' exactly once in the plan")

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog id for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp)")
    task: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    # reducer: results from workers get concatinated automatically
    sections: Annotated[List[str], operator.add]
    final: str

# %%
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
def orchestrator(state: State) -> dict:
    plan = llm.with_structured_output(Plan).invoke(
        [
            SystemMessage(
                content="You are a senior technical writer and developer advocate. Your job is to produce a highly actionable outline for a technical blog post.\n\n"
                "Hard requirements:\n"
                "- Create 5–7 sections (tasks) that fit a technical blog.\n"
                "- Each section must include:\n"
                "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                "  2) 3–5 bullets that are concrete, specific, and non-overlapping\n"
                "  3) target word count (120–450)\n\n"
                "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                "Make it technical (not generic):\n"
                "- Assume the reader is a developer; use correct terminology.\n"
                "- Prefer design/engineering structure:\n"
                "  problem → intuition → approach → implementation → trade-offs → testing/observability → conclusion.\n\n"
                "- Bullets must be actionable and testable\n"
                "  (e.g., 'Show a minimal code snippet for X',\n"
                "  'Explain why Y fails under Z condition',\n"
                "  'Add a checklist for production readiness').\n\n"
                "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                "  * a minimal working example (MWE) or code sketch\n"
                "  * edge cases / failure modes\n"
                "  * performance/cost considerations\n"
                "  * security/privacy considerations (if relevant)\n"
                "  * debugging tips / observability (logs, metrics, traces)\n\n"
                "- Avoid vague bullets like 'Explain X' or 'Discuss Y'.\n"
                "  Every bullet should state what to build/compare/measure/verify.\n\n"
                "Ordering guidance:\n"
                "- Start with a crisp intro and problem framing.\n"
                "- Build core concepts before advanced details.\n"
                "- Include one section for common mistakes and how to avoid them.\n"
                "- End with a practical summary/checklist and next steps.\n\n"
                "Output must strictly match the Plan schema."
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )
    return {"plan": plan}

# %%
def fanout(state: State):
    return [Send("worker", {"task": task, "topic": state['topic'], "plan": state['plan']}) for task in state['plan'].task]

# %%
def worker(payload: dict) -> dict:
    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullet_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
                content="You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
                "Hard constraints:\n"
                "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
                "- Stay close to the Target words (±15%).\n"
                "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
                "Technical quality bar:\n"
                "- Be precise and implementation-oriented (developers should be able to apply it).\n"
                "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
                "- When relevant, include at least one of:\n"
                "  * a small code snippet (minimal, correct, and idiomatic)\n"
                "  * a tiny example input/output\n"
                "  * a checklist of steps\n"
                "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
                "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
                "- Call out edge cases / failure modes and what to do about them.\n"
                "- If you mention a best practice, add the 'why' in one sentence.\n\n"
                "Markdown style:\n"
                "- Start with a '## <Section Title>' heading.\n"
                "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
                "- Avoid fluff. Avoid marketing language.\n"
                "- If you include code, keep it focused on the bullet being addressed."
            ),
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target Words: {task.target_words}\n"
                    f"Bullets: {bullet_text}\n"
                    "Return only the section content in Markdown"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
def reducer(state: State) -> dict:
    title = state['plan'].blog_title
    body = "\n\n".join(state["sections"]).strip()
    
    finally_md = f"# {title}\n\n{body}\n"
    
    # save to the file
    filename = title.lower().replace(" ", "_") + ".md"
    output_path = Path(filename)
    output_path.write_text(finally_md, encoding="utf-8")
    
    return {"final": finally_md}

# %%
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

# %%
g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer"),
g.add_edge("reducer", END)

app = g.compile()

# %%
app

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []})

# %%
print(out["final"])
# Out:
# # Mastering Self-Attention: Core Concepts, Implementation, and Best Practices
#
# ## Introduction to Self-Attention
#
# Self-attention is a neural mechanism that computes a representation of a sequence by relating each element (token) to every other element within the same sequence. Unlike traditional attention, which typically links an external query to keys and values from another sequence (e.g., encoder-decoder attention), self-attention operates internally, allowing tokens to attend to each other directly. This differs from convolutional operations, which use fixed-size local kernels and rely on stacked layers to capture broader context.
#
# The core intuition behind self-attention is its ability to capture dependencies regardless of their distance in the sequence. For example, a word at the start of a sentence can directly attend to a related word near the end without passing through intermediate positions. This flexibility contrasts with RNNs or CNNs, where information must propagate sequentially or layer-by-layer, making long-range dependency modeling inefficient.
#
# The primary problem self-attention solves is efficient modeling of long-range dependencies. It computes interactions between all tokens simultaneously in parallel, offering better scalability and stronger contextual understanding compared to recurrence-based or convolutional approaches.
#
# Self-attention underpins modern architectures like Transformers, which have revolutionized natural language processing (NLP) tasks including machine translation, text classification, and language generation by providing powerful sequence representations.
#
# ### Token Interaction via Self-Attention
#
# ```
# Tokens:       [T1]  [T2]  [T3]  [T4]
# Self-Attention Scores:
# T1 -> {T1:0.2, T2:0.5, T3:0.1, T4:0.2}
# T2 -> {T1:0.3, T2:0.1, T3:0.4, T4:0.2}
# T3 -> {T1:0.25, T2:0.25, T3:0.25, T4:0.25}
# T4 -> {T1:0.1, T2:0.3, T3:0.4, T4:0.2}
# ```
#
# Each token computes attention scores to all tokens, weighting their influence dynamically and aggregating their representations accordingly. This all-to-all interaction enables the model to focus adaptively on relevant parts of the sequence, forming context-aware embeddings critical for downstream tasks.
#
# ## Mathematical Formulation and Core Mechanism
#
# Self-attention operates by transforming input token embeddings into queries, keys, and values via learned projection matrices, then computing weighted sums of values based on attention scores.
#
# ### Query, Key, and Value Projections
#
# Given an input sequence of token embeddings \( X \in \mathbb{R}^{L \times d} \) where \( L \) is the sequence length and \( d \) is the embedding dimension, self-attention uses three learned parameter matrices:
#
# \[
# W^Q \in \mathbb{R}^{d \times d_k}, \quad W^K \in \mathbb{R}^{d \times d_k}, \quad W^V \in \mathbb{R}^{d \times d_v}
# \]
#
# The queries, keys, and values are computed as:
#
# \[
# Q = X W^Q, \quad K = X W^K, \quad V = X W^V
# \]
#
# Each token’s query vector \( q_i \) is compared against every key \( k_j \) to score the relative relevance.
#
# ### Scaled Dot-Product Attention
#
# The raw attention score between token \( i \) and token \( j \) is the dot product of their query and key vectors:
#
# \[
# \text{score}(i,j) = q_i \cdot k_j^T = Q K^T
# \]
#
# To prevent excessively large dot products that can saturate softmax gradients, scale the scores by \( \frac{1}{\sqrt{d_k}} \):
#
# \[
# \text{scaled scores} = \frac{Q K^T}{\sqrt{d_k}}
# \]
#
# Applying the softmax function across the keys for each query produces attention weights:
#
# \[
# \alpha_{ij} = \mathrm{softmax}_j \left( \frac{q_i \cdot k_j^T}{\sqrt{d_k}} \right)
# = \frac{\exp\left(\frac{q_i \cdot k_j^T}{\sqrt{d_k}}\right)}{\sum_{m=1}^L \exp\left(\frac{q_i \cdot k_m^T}{\sqrt{d_k}}\right)}
# \]
#
# The output for each token is the weighted sum of the values:
#
# \[
# \mathrm{Attention}(Q,K,V) = \alpha V = \mathrm{softmax}\left(\frac{QK^T}{\sqrt{d_k}}\right) V
# \]
#
# ### Minimal Implementation Example (Python + NumPy)
#
# ```python
# import numpy as np
#
# def self_attention(X, W_Q, W_K, W_V):
#     d_k = W_Q.shape[1]
#     Q = X @ W_Q  # (L, d_k)
#     K = X @ W_K  # (L, d_k)
#     V = X @ W_V  # (L, d_v)
#
#     scores = Q @ K.T / np.sqrt(d_k)  # (L, L)
#     weights = np.exp(scores - np.max(scores, axis=1, keepdims=True))  # stability trick
#     weights /= weights.sum(axis=1, keepdims=True)  # softmax across keys
#
#     output = weights @ V  # (L, d_v)
#     return output
#
# # Example usage
# L = 4  # Length of sequence
# d = 8  # Embedding dimension
# d_k = d_v = 8
#
# np.random.seed(0)
# X = np.random.rand(L, d)
# W_Q = np.random.rand(d, d_k)
# W_K = np.random.rand(d, d_k)
# W_V = np.random.rand(d, d_v)
#
# out = self_attention(X, W_Q, W_K, W_V)
# print(out)
# ```
#
# ### Multi-Head Attention and Multiple Projections
#
# Multi-head attention splits the embedding dimension \( d \) into \( h \) heads, each with separate projection matrices:
#
# \[
# W_i^Q, W_i^K, W_i^V \quad \text{for} \quad i=1,...,h; \quad W_i^Q, W_i^K, W_i^V \in \mathbb{R}^{d \times d_k}
# \]
#
# Each head independently computes attention, enabling the model to capture diverse relationships. The heads’ outputs are concatenated and projected with \( W^O \in \mathbb{R}^{h d_v \times d} \).
#
# This allows the model to attend to information at different representation subspaces and positions simultaneously.
#
# ### Computational Complexity
#
# Self-attention requires:
#
# - Computing similarity scores: \( O(L^2 d_k) \)
# - Applying softmax and multiplications: \( O(L^2 d_v) \)
# - Projections: \( O(L d \times d_k) \)
#
# Overall, the dominant cost is \( O(L^2 d) \) due to pairwise token interactions, making it quadratic in sequence length. Increasing \( d \) impacts linear overhead. This quadratic scaling can be prohibitive for large \( L \), motivating approximate or sparse attention methods for long sequences.
#
# ## Implementation Details and Performance Optimizations
#
# Implementing self-attention efficiently requires careful handling of batched inputs, memory management, and hardware-aware optimizations.
#
# ### Efficient Batching and Tensor Operations
#
# Handle multiple sequences and heads by leveraging built-in batch dimensions and multi-head layouts in frameworks like PyTorch or TensorFlow. Typically, input tensors have shape `[batch_size, seq_len, embed_dim]`. After linear projections to queries, keys, and values, reshape and transpose for multi-head attention:
#
# ```python
# # PyTorch example for reshaping Q,K,V for multi-head attention
# qkv = qkv.view(batch_size, seq_len, num_heads, head_dim)
# qkv = qkv.permute(0, 2, 1, 3)  # [batch, heads, seq_len, head_dim]
# ```
#
# This allows parallel computation across heads and sequences using efficient batched matrix multiplications (`torch.matmul`). Avoid Python loops to maintain GPU/TPU utilization.
#
# ### Memory Usage and Optimization Strategies
#
# Self-attention’s quadratic complexity in sequence length can cause high memory pressure. Mitigate this by:
#
# - **Mixed precision training**: Use FP16/BF16 for computations and FP32 for critical accumulations to reduce memory footprint and increase throughput with tools like PyTorch’s `torch.cuda.amp`.
# - **Gradient checkpointing**: Recompute intermediate activations on backward passes rather than storing them, significantly reducing GPU memory at the expense of some extra computation.
# - **Batch size tuning**: Balance batch sizes to fit GPU memory while fully utilizing hardware.
#
# ### Trade-Offs: Sequence Length, Model Size, Inference Speed
#
# Self-attention’s time and space complexity grow quadratically with sequence length (`O(seq_len²)`) but linearly with model size. Key trade-offs include:
#
# - Longer sequences increase computation and memory exponentially, affecting batch size and latency.
# - Larger model sizes (more heads or layers) increase expressiveness but proportionally raise computation and memory cost.
# - For inference speed, truncating sequences or using approximate attention techniques can reduce complexity but may sacrifice accuracy.
#
# ### Debugging Tips
#
# - **Visualize attention weights**: Plot attention maps to verify if the model attends to reasonable tokens. Unexpected uniform or zeroed maps could indicate issues.
# - **Monitor gradient norms**: Check gradient magnitudes of query/key/value layers to detect vanishing/exploding gradients.
# - **Check shapes rigorously**: Misaligned shapes in Q,K,V often cause silent broadcasting bugs or runtime errors.
# - For example, visualize attention using `matplotlib`:
#
# ```python
# import matplotlib.pyplot as plt
#
# def plot_attention_weights(weights, layer=0, head=0):
#     attn = weights[layer][head].detach().cpu().numpy()
#     plt.imshow(attn, cmap='viridis')
#     plt.title(f'Attention weights - Layer {layer} Head {head}')
#     plt.colorbar()
#     plt.show()
# ```
#
# ### Performance Considerations on GPUs and CPUs
#
# - **GPUs** excel at parallel batched matrix multiplications, making fused kernels beneficial. Frameworks often provide optimized fused attention kernels that combine scaling, masking, softmax, and dropout into one GPU kernel.
# - **Kernel fusion** reduces memory reads/writes and kernel launch overhead, boosting throughput.
# - On **CPUs**, leverage libraries like Intel MKL-DNN (OneDNN) and multi-threading via OpenMP or TBB. Batch dimensions can be folded into existing BLAS calls to parallelize matrix multiplications.
# - When GPU memory is limited, distribute attention computation across devices or use attention approximation algorithms.
#
# By following these guidelines, you can build self-attention modules that balance memory, speed, and accuracy suitable for production deployment.
#
# ## Common Mistakes When Using Self-Attention and How to Avoid Them
#
# When implementing self-attention, several pitfalls can degrade model performance or cause runtime errors. Here are frequent mistakes and practical fixes.
#
# ### 1. Omitting the Scaling Factor
#
# The scaled dot-product attention divides the raw attention logits by \(\sqrt{d_k}\) (where \(d_k\) is the query/key dimension). This prevents the softmax input values from becoming too large, which otherwise leads to vanishing gradients.
#
# **How to verify:**
#
# - Check the attention logits before softmax have reasonable magnitude (typically ~1).
# - Inspect the resulting attention distribution shape; without scaling, probabilities may saturate (values close to 0 or 1).
#
# **Fix:**
#
# ```python
# scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)
# attention = torch.softmax(scores, dim=-1)
# ```
#
# ### 2. Ignoring Padding Tokens or Masking
#
# Self-attention must ignore padding tokens by applying masks. Failing to mask leads to attention leakage, where model attends to irrelevant padding, harming training and inference.
#
# **Best practice:**
#
# - Use boolean masks to zero out attention logits at padding positions before softmax.
# - Test edge cases with inputs heavily padded or completely padded sequences.
#
# ```python
# scores = scores.masked_fill(padding_mask == 0, float('-inf'))
# attention = torch.softmax(scores, dim=-1)
# ```
#
# ### 3. Misconfiguring Multi-Head Dimensions
#
# A common source of bugs is inconsistent dimensions between the input, the number of heads, and head dimension sizes.
#
# **Checklist to avoid dimension mismatches:**
#
# - Confirm: `embed_dim = num_heads * head_dim`
# - Verify reshaping steps from `[batch_size, seq_len, embed_dim]` to `[batch_size, num_heads, seq_len, head_dim]`
# - Check queries, keys, and values share the same embedding dimension before split
#
# ### 4. Overlooking Numerical Stability in Softmax
#
# Softmax can produce NaNs or Infs if scores are large or poorly scaled.
#
# **Solutions:**
#
# - Use numerically stable softmax implementations (e.g., PyTorch’s `torch.softmax` manages stability internally).
# - Subtract max value in logits before softmax to stabilize:
#
# ```python
# scores = scores - scores.max(dim=-1, keepdim=True)[0]
# attention = torch.softmax(scores, dim=-1)
# ```
#
# - Monitor training logs for NaN or Inf values in attention weights.
#
# ### 5. Neglecting to Observe Attention Weights During Training
#
# Attention weights provide critical insights into model behavior and debugging.
#
# **Recommendations:**
#
# - Add logging hooks that extract and save attention matrices during training.
# - Periodically visualize attention heatmaps to spot anomalies like uniform distributions or collapsed attention.
# - Use tools such as TensorBoard or matplotlib for visualization.
#
# ---
#
# Adhering to these practices ensures stable, correct self-attention implementations and easier debugging workflows.
#
# ## Edge Cases, Extensions, and Security Considerations
#
# Self-attention faces challenges when dealing with extremely long input sequences and rare tokens. Computational complexity grows quadratically with sequence length \(O(n^2)\), causing memory bottlenecks and slower training/inference. Accuracy may degrade as longer contexts dilute relevant signals or increase noise. Rare tokens pose problems by having poorly learned embeddings, leading to unstable attention distributions and reduced model confidence. Benchmarking with datasets containing sequences of length 1,000+ tokens or heavy-tailed vocabularies often reveals performance drops in both accuracy and throughput.
#
# To address scalability, sparse and local attention variants are commonly used:
#
# - **Sparse attention:** Only computes attention on a subset of token pairs (e.g., fixed patterns or learned sparse masks). This reduces complexity from \(O(n^2)\) to near-linear, improving runtime and memory usage.
# - **Local attention:** Restricts attention to a fixed window size around each token, appropriate when local context dominates meaning.
#
# These methods trade off some global context for efficiency and can be selected based on task requirements and input characteristics.
#
# Attention mechanisms also pose privacy risks in production. Attention scores may inadvertently encode sensitive information from inputs, as they highlight which tokens influenced predictions. An adversary with access to attention weights can potentially infer parts of private data, especially in models handling personal text.
#
# Mitigations include:
#
# - **Differential privacy:** Adds noise to gradients or attention weights during training, limiting information leakage.
# - **Attention masking:** Explicitly masks or obfuscates tokens that contain sensitive data to prevent attention weights from revealing them.
#
# Evaluating attention robustness involves measuring sensitivity to small input perturbations. For example, swapping rare tokens or introducing synonym replacements can lead to large changes in attention maps and model outputs, signaling low robustness. Tracking attention score variance with respect to controlled input changes can guide improvement efforts such as adversarial training or input smoothing.
#
# **Checklist for robustness and privacy-aware self-attention:**
#
# - Benchmark on varying sequence lengths and rare-token distributions.
# - Consider sparse/local attention for long sequences to reduce cost.
# - Analyze attention weight distributions for potential data leakage.
# - Employ differential privacy techniques or masked attention to protect sensitive data.
# - Test attention sensitivity with input perturbations to evaluate robustness.
#
# This comprehensive approach ensures that self-attention remains effective, efficient, and secure across diverse real-world scenarios.
#
# ## Putting It All Together: A Checklist and Next Steps for Developers
#
# To implement self-attention effectively, keep these essential steps in mind:
# - Define **queries (Q)**, **keys (K)**, and **values (V)** by linear projections of the input embeddings.
# - Compute attention scores as the scaled dot-product: \( \text{scores} = \frac{QK^T}{\sqrt{d_k}} \).
# - Apply **masking** to attention scores for padding tokens or to preserve causality in autoregressive models.
# - Use softmax over masked scores to get attention weights, then compute weighted sum with values as output.
# - Apply a final linear projection and optional dropout to produce the self-attention output.
#
# ### Production Readiness Checklist
# - [ ] **Input preprocessing:** Normalize and batch inputs uniformly; handle padding tokens consistently.
# - [ ] **Proper masking:** Implement padding masks and causal masks depending on the task.
# - [ ] **Numerical stability:** Use stable implementations for softmax (e.g., subtract max before exponentiation).
# - [ ] **Observability:** Log attention weights and intermediate representations for debugging and interpretability.
# - [ ] **Performance:** Profile GPU/TPU usage and optimize matrix multiplications, considering mixed precision where appropriate.
#
# ### Recommended Tools and Resources
# - Use **[Hugging Face Transformers](https://huggingface.co/docs/transformers/)** for pre-built self-attention modules optimized for various hardware.
# - Explore **TensorFlow Addons** or **PyTorch's nn.MultiheadAttention** for native implementations.
# - For visualization and debugging, tools like **Weights & Biases** help track attention maps over training.
#
# ### Further Reading and Exploration
# - Start with the seminal paper: *“Attention Is All You Need”* by Vaswani et al., 2017, which introduced scaled dot-product attention.
# - Review recent works covering improvements like sparse attention, linearized attention, and relative positional encoding.
# - Recommended tutorials: Jay Alammar’s annotated Transformer blog and the Stanford CS224n course lectures.
#
# ### Encourage Experimentation
# - Try variants such as **relative positional encodings** to better capture sequence order without fixed indices.
# - Implement **attention pruning** or sparsity to improve model efficiency and interpretability when scaling.
# - Experiment with hybrid models combining self-attention with convolution or recurrence for domain-specific gains.
#
# Following this checklist and leveraging these resources will help you build robust, interpretable, and scalable self-attention models aligned with current research and best practices.
#
# ## Conclusion: The Impact and Future of Self-Attention
#
# Self-attention has fundamentally transformed sequence modeling by overcoming the limitations of RNNs and CNNs. Unlike those architectures, self-attention captures global dependencies in sequences with parallelizable computation, enabling breakthroughs in NLP and beyond.
#
# Current research addresses the challenge of scaling self-attention to longer sequences and diverse modalities such as vision and audio. Innovations like sparse attention, linearized attention, and efficient memory mechanisms help reduce quadratic complexity, making it feasible to process high-resolution images or long audio streams.
#
# There is also a strong trend toward hybrid architectures that combine self-attention layers with convolutional or recurrent components. These hybrids aim to balance efficiency, inductive biases, and performance for different tasks, offering practical routes to reduce compute cost and latency without sacrificing accuracy.
#
# To continue mastering self-attention, engage with community forums (e.g., Hugging Face forums, Transformer-related GitHub discussions), explore leaderboards and benchmarks (such as GLUE or Long-Range Arena), and contribute to open-source implementations. This hands-on involvement accelerates understanding and uncovers emerging best practices.
#
# Finally, we encourage you to integrate self-attention mechanisms not only in research experiments but also in production systems. Their versatility and power make them key enablers for next-generation models across NLP, vision, and multimodal domains.
